# %%
# patterns :
# *
# * *
# * * *
# * * * *

# %%
for i in range(1,5+1) :
    for j in range(i):
        print('* ', end='')
        
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
# 1 
# 1 2 1 
# 1 2 3 2 1 
# 1 2 3 4 3 2 1

# %%
for i in range(1 ,5 ):
    for j in range(i):
        print(j+1, end='')
    for j in range(i-1, 0, -1):
        print(j , end='')
    print()
# Out:
# 1
# 121
# 12321
# 1234321

# %%
#  StairCase  
#     *
#   * *
# * * * 
#* * * *

# %%
n = int(input("Enter n : "))
# Out:
# Enter n : 5

# %%
for i in range(1 , n):
    for j in range(n-i, 0, -1 ): 
        print(" ",end='')
    for k in range(i):
        print('*' , end='')
    print()
# Out:
#     *
#    **
#   ***
#  ****

# %%
n = 5
for i in range(1,n+1):
    print (" "*(n-i) + "#"*i)
# Out:
#      #
#     # #
#    # # #
#   # # # #
#  # # # # #
